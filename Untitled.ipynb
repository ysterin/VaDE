# %%
import torch

torch.manual_seed(42)
torch.
# Out:
# Signature: torch.random.set_rng_state(new_state) -> None
# Docstring:
# Sets the random number generator state.
#
# Args:
#     new_state (torch.ByteTensor): The desired state
# File:      ~/projects/VaDE/vade/lib/python3.8/site-packages/torch/random.py
# Type:      function

# %%
torch.randint(10000000, size=(10,))[0]
# Out:
# 8409749

# %%
import torch
torch.random.seed()
from torch import nn
from torch.utils.data import DataLoader, Dataset, IterableDataset, TensorDataset, Subset, ConcatDataset
from torchvision.datasets import MNIST, FashionMNIST
import pytorch_lightning as pl
from triplet_vade import TripletDataset, CombinedDataset, TripletVaDE
from autoencoder import SimpleAutoencoder, ClusteringEvaluationCallback, cluster_acc
from sklearn.mixture import GaussianMixture
from pl_modules import PLVaDE

# %%
class MNISTDataModule(pl.LightningDataModule):
    def __init__(self, path='data', bs=256, dataset='mnist', data_size=None):
        super(MNISTDataModule, self).__init__()
        self.path = path
        self.batch_size = bs
        self.dataset = dataset
        self.data_size = data_size
    
    def setup(self, stage_name=None):
        self.train_ds = MNIST(self.path, download=True, train=True)
        self.valid_ds = MNIST(self.path, download=True, train=False)
        if self.dataset == 'mnist':
            self.train_ds = MNIST("data", download=True)
            self.valid_ds = MNIST("data", download=True, train=False)
        elif self.dataset == 'fmnist':
            self.train_ds = FashionMNIST("data", download=True)
            self.valid_ds = FashionMNIST("data", download=True, train=False)
        def to_tensor_dataset(ds):
            X = ds.data.view(-1, 28**2).float()/255.
            X = torch.cat([X, torch.rand(X.shape[0], 1000)], dim=1)
            return TensorDataset(X, ds.targets)
        self.train_ds, self.valid_ds = map(to_tensor_dataset, [self.train_ds, self.valid_ds])
        if self.data_size is not None:
            n_sample = self.data_size
            to_subset = lambda ds: torch.utils.data.random_split(ds, 
                                                                 [n_sample, len(ds) - n_sample],
                                                                 torch.Generator().manual_seed(42))[0]
            self.train_ds, self.valid_ds = map(to_subset, [self.train_ds, self.valid_ds])
        self.all_ds = ConcatDataset([self.train_ds, self.valid_ds])
                
    def train_dataloader(self):
        return DataLoader(self.train_ds, batch_size=self.batch_size)
    
    def val_dataloader(self):
        return DataLoader(self.valid_ds, batch_size=self.batch_size)
    
dm = MNISTDataModule()

# %%
model = SimpleAutoencoder(n_neurons=[28**2 + 1000, 512, 512, 2048, 10])
logger = pl.loggers.WandbLogger(project='Corrupted_MNIST')
trainer = pl.Trainer(gpus=1, progress_bar_refresh_rate=20, max_epochs=100, logger=logger,
                     callbacks=[ClusteringEvaluationCallback(ds_type='all')])
dm = MNISTDataModule(data_size=None, dataset='mnist')
trainer.fit(model, datamodule=dm)
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type       | Params
# ---------------------------------------
# 0 | encoder | Sequential | 2.2 M
# 1 | decoder | Sequential | 2.2 M
# ---------------------------------------
# 4.5 M     Trainable params
# 0         Non-trainable params
# 4.5 M     Total params
# Training: 0it [00:00, ?it/s]
# /home/shuki/projects/VaDE/vade/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# /home/shuki/projects/VaDE/vade/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0:  87%|████████▋ | 240/275 [00:01<00:00, 129.93it/s, loss=0.483, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 275/275 [00:02<00:00, 136.42it/s, loss=0.481, v_num=og0h]
# Epoch 1:  87%|████████▋ | 240/275 [00:01<00:00, 131.21it/s, loss=0.459, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 275/275 [00:01<00:00, 137.58it/s, loss=0.458, v_num=og0h]
# Epoch 2:  87%|████████▋ | 240/275 [00:01<00:00, 133.57it/s, loss=0.451, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 275/275 [00:01<00:00, 139.84it/s, loss=0.451, v_num=og0h]
# Epoch 3:  87%|████████▋ | 240/275 [00:01<00:00, 131.04it/s, loss=0.447, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 275/275 [00:02<00:00, 137.16it/s, loss=0.446, v_num=og0h]
# Epoch 4:  87%|████████▋ | 240/275 [00:01<00:00, 131.84it/s, loss=0.443, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 275/275 [00:01<00:00, 138.09it/s, loss=0.443, v_num=og0h]
# Epoch 5:  87%|████████▋ | 240/275 [00:01<00:00, 130.84it/s, loss=0.441, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 275/275 [00:02<00:00, 137.19it/s, loss=0.44, v_num=og0h]
# Epoch 6:  87%|████████▋ | 240/275 [00:01<00:00, 128.36it/s, loss=0.439, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 275/275 [00:02<00:00, 134.69it/s, loss=0.439, v_num=og0h]
# Epoch 7:  87%|████████▋ | 240/275 [00:01<00:00, 131.26it/s, loss=0.438, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 275/275 [00:02<00:00, 137.44it/s, loss=0.437, v_num=og0h]
# Epoch 8:  87%|████████▋ | 240/275 [00:01<00:00, 130.72it/s, loss=0.437, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████| 275/275 [00:02<00:00, 136.95it/s, loss=0.437, v_num=og0h]
# Epoch 9:  87%|████████▋ | 240/275 [00:01<00:00, 128.44it/s, loss=0.436, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 9: 100%|██████████| 275/275 [00:02<00:00, 134.88it/s, loss=0.436, v_num=og0h]
# Epoch 10:  87%|████████▋ | 240/275 [00:01<00:00, 131.94it/s, loss=0.435, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 10: 100%|██████████| 275/275 [00:01<00:00, 138.09it/s, loss=0.435, v_num=og0h]
# Epoch 11:  87%|████████▋ | 240/275 [00:01<00:00, 134.59it/s, loss=0.435, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 11: 100%|██████████| 275/275 [00:01<00:00, 140.77it/s, loss=0.435, v_num=og0h]
# Epoch 12:  87%|████████▋ | 240/275 [00:01<00:00, 129.50it/s, loss=0.434, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 12: 100%|██████████| 275/275 [00:02<00:00, 135.88it/s, loss=0.434, v_num=og0h]
# Epoch 13:  87%|████████▋ | 240/275 [00:01<00:00, 132.02it/s, loss=0.434, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 13: 100%|██████████| 275/275 [00:01<00:00, 138.18it/s, loss=0.434, v_num=og0h]
# Epoch 14:  87%|████████▋ | 240/275 [00:01<00:00, 133.23it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 14: 100%|██████████| 275/275 [00:01<00:00, 139.43it/s, loss=0.434, v_num=og0h]
# Epoch 15:  87%|████████▋ | 240/275 [00:01<00:00, 128.06it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 15: 100%|██████████| 275/275 [00:02<00:00, 134.39it/s, loss=0.433, v_num=og0h]
# Epoch 16:  87%|████████▋ | 240/275 [00:01<00:00, 133.45it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 16: 100%|██████████| 275/275 [00:01<00:00, 139.76it/s, loss=0.433, v_num=og0h]
# Epoch 17:  87%|████████▋ | 240/275 [00:01<00:00, 133.17it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 17: 100%|██████████| 275/275 [00:01<00:00, 139.36it/s, loss=0.433, v_num=og0h]
# Epoch 18:  87%|████████▋ | 240/275 [00:01<00:00, 130.24it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 18: 100%|██████████| 275/275 [00:02<00:00, 136.56it/s, loss=0.433, v_num=og0h]
# Epoch 19:  87%|████████▋ | 240/275 [00:01<00:00, 132.44it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 19: 100%|██████████| 275/275 [00:01<00:00, 138.66it/s, loss=0.433, v_num=og0h]
# Epoch 20:  87%|████████▋ | 240/275 [00:01<00:00, 134.43it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 20: 100%|██████████| 275/275 [00:01<00:00, 140.66it/s, loss=0.432, v_num=og0h]
# Epoch 21:  87%|████████▋ | 240/275 [00:01<00:00, 131.59it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 21: 100%|██████████| 275/275 [00:01<00:00, 137.97it/s, loss=0.432, v_num=og0h]
# Epoch 22:  87%|████████▋ | 240/275 [00:01<00:00, 133.36it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 22: 100%|██████████| 275/275 [00:01<00:00, 139.52it/s, loss=0.432, v_num=og0h]
# Epoch 23:  87%|████████▋ | 240/275 [00:01<00:00, 134.69it/s, loss=0.433, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 23: 100%|██████████| 275/275 [00:01<00:00, 140.82it/s, loss=0.432, v_num=og0h]
# Epoch 24:  87%|████████▋ | 240/275 [00:01<00:00, 130.27it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 24: 100%|██████████| 275/275 [00:02<00:00, 136.62it/s, loss=0.432, v_num=og0h]
# Epoch 25:  87%|████████▋ | 240/275 [00:01<00:00, 134.08it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 25: 100%|██████████| 275/275 [00:01<00:00, 140.11it/s, loss=0.432, v_num=og0h]
# Epoch 26:  87%|████████▋ | 240/275 [00:01<00:00, 131.40it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 26: 100%|██████████| 275/275 [00:01<00:00, 137.68it/s, loss=0.432, v_num=og0h]
# Epoch 27:  87%|████████▋ | 240/275 [00:01<00:00, 129.21it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 27: 100%|██████████| 275/275 [00:02<00:00, 135.51it/s, loss=0.432, v_num=og0h]
# Epoch 28:  87%|████████▋ | 240/275 [00:01<00:00, 132.95it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 28: 100%|██████████| 275/275 [00:01<00:00, 139.23it/s, loss=0.432, v_num=og0h]
# Epoch 29:  87%|████████▋ | 240/275 [00:01<00:00, 132.71it/s, loss=0.432, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 29: 100%|██████████| 275/275 [00:01<00:00, 138.98it/s, loss=0.431, v_num=og0h]
# Epoch 30:  87%|████████▋ | 240/275 [00:01<00:00, 129.84it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 30: 100%|██████████| 275/275 [00:02<00:00, 136.28it/s, loss=0.431, v_num=og0h]
# Epoch 31:  87%|████████▋ | 240/275 [00:01<00:00, 132.76it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 31: 100%|██████████| 275/275 [00:01<00:00, 138.90it/s, loss=0.431, v_num=og0h]
# Epoch 32:  87%|████████▋ | 240/275 [00:01<00:00, 133.00it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 32: 100%|██████████| 275/275 [00:01<00:00, 139.30it/s, loss=0.431, v_num=og0h]
# Epoch 33:  87%|████████▋ | 240/275 [00:01<00:00, 131.53it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 33: 100%|██████████| 275/275 [00:01<00:00, 137.68it/s, loss=0.431, v_num=og0h]
# Epoch 34:  87%|████████▋ | 240/275 [00:01<00:00, 128.30it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 34: 100%|██████████| 275/275 [00:02<00:00, 134.66it/s, loss=0.431, v_num=og0h]
# Epoch 35:  87%|████████▋ | 240/275 [00:01<00:00, 131.29it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 35: 100%|██████████| 275/275 [00:02<00:00, 137.50it/s, loss=0.431, v_num=og0h]
# Epoch 36:  87%|████████▋ | 240/275 [00:01<00:00, 132.54it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 36: 100%|██████████| 275/275 [00:01<00:00, 138.68it/s, loss=0.431, v_num=og0h]
# Epoch 37:  87%|████████▋ | 240/275 [00:01<00:00, 129.59it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 37: 100%|██████████| 275/275 [00:02<00:00, 135.99it/s, loss=0.431, v_num=og0h]
# Epoch 38:  87%|████████▋ | 240/275 [00:01<00:00, 132.78it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 38: 100%|██████████| 275/275 [00:01<00:00, 138.93it/s, loss=0.431, v_num=og0h]
# Epoch 39:  87%|████████▋ | 240/275 [00:01<00:00, 129.94it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 39: 100%|██████████| 275/275 [00:02<00:00, 136.23it/s, loss=0.43, v_num=og0h]
# Epoch 40:  87%|████████▋ | 240/275 [00:01<00:00, 128.45it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 40: 100%|██████████| 275/275 [00:02<00:00, 134.83it/s, loss=0.43, v_num=og0h]
# Epoch 41:  87%|████████▋ | 240/275 [00:01<00:00, 132.55it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 41: 100%|██████████| 275/275 [00:01<00:00, 138.63it/s, loss=0.43, v_num=og0h]
# Epoch 42:  87%|████████▋ | 240/275 [00:01<00:00, 131.05it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 42: 100%|██████████| 275/275 [00:02<00:00, 137.30it/s, loss=0.43, v_num=og0h]
# Epoch 43:  87%|████████▋ | 240/275 [00:01<00:00, 126.87it/s, loss=0.431, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 43: 100%|██████████| 275/275 [00:02<00:00, 133.27it/s, loss=0.43, v_num=og0h]
# Epoch 44:  87%|████████▋ | 240/275 [00:01<00:00, 133.52it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 44: 100%|██████████| 275/275 [00:01<00:00, 139.86it/s, loss=0.43, v_num=og0h]
# Epoch 45:  87%|████████▋ | 240/275 [00:01<00:00, 134.67it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 45: 100%|██████████| 275/275 [00:01<00:00, 140.91it/s, loss=0.43, v_num=og0h]
# Epoch 46:  87%|████████▋ | 240/275 [00:01<00:00, 129.24it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 46: 100%|██████████| 275/275 [00:02<00:00, 135.64it/s, loss=0.43, v_num=og0h]
# Epoch 47:  87%|████████▋ | 240/275 [00:01<00:00, 130.93it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 47: 100%|██████████| 275/275 [00:02<00:00, 137.19it/s, loss=0.43, v_num=og0h]
# Epoch 48:  87%|████████▋ | 240/275 [00:01<00:00, 131.97it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 48: 100%|██████████| 275/275 [00:01<00:00, 138.19it/s, loss=0.43, v_num=og0h]
# Epoch 49:  87%|████████▋ | 240/275 [00:01<00:00, 128.44it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 49: 100%|██████████| 275/275 [00:02<00:00, 134.86it/s, loss=0.43, v_num=og0h]
# Epoch 50:  87%|████████▋ | 240/275 [00:01<00:00, 132.75it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 50: 100%|██████████| 275/275 [00:01<00:00, 139.11it/s, loss=0.43, v_num=og0h]
# Epoch 51:  87%|████████▋ | 240/275 [00:01<00:00, 131.18it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 51: 100%|██████████| 275/275 [00:02<00:00, 137.40it/s, loss=0.43, v_num=og0h]
# Epoch 52:  87%|████████▋ | 240/275 [00:01<00:00, 131.53it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 52: 100%|██████████| 275/275 [00:01<00:00, 137.87it/s, loss=0.43, v_num=og0h]
# Epoch 53:  87%|████████▋ | 240/275 [00:01<00:00, 133.14it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 53: 100%|██████████| 275/275 [00:01<00:00, 139.39it/s, loss=0.43, v_num=og0h]
# Epoch 54:  87%|████████▋ | 240/275 [00:01<00:00, 132.69it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 54: 100%|██████████| 275/275 [00:01<00:00, 139.05it/s, loss=0.43, v_num=og0h]
# Epoch 55:  87%|████████▋ | 240/275 [00:01<00:00, 128.41it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 55: 100%|██████████| 275/275 [00:02<00:00, 134.76it/s, loss=0.43, v_num=og0h]
# Epoch 56:  87%|████████▋ | 240/275 [00:01<00:00, 130.81it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 56: 100%|██████████| 275/275 [00:02<00:00, 137.02it/s, loss=0.43, v_num=og0h]
# Epoch 57:  87%|████████▋ | 240/275 [00:01<00:00, 130.85it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 57: 100%|██████████| 275/275 [00:02<00:00, 137.06it/s, loss=0.43, v_num=og0h]
# Epoch 58:  87%|████████▋ | 240/275 [00:01<00:00, 127.70it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 58: 100%|██████████| 275/275 [00:02<00:00, 133.94it/s, loss=0.429, v_num=og0h]
# Epoch 59:  87%|████████▋ | 240/275 [00:01<00:00, 130.18it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 59: 100%|██████████| 275/275 [00:02<00:00, 136.18it/s, loss=0.429, v_num=og0h]
# Epoch 60:  87%|████████▋ | 240/275 [00:01<00:00, 131.55it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 60: 100%|██████████| 275/275 [00:01<00:00, 137.72it/s, loss=0.429, v_num=og0h]
# Epoch 61:  87%|████████▋ | 240/275 [00:01<00:00, 129.69it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 61: 100%|██████████| 275/275 [00:02<00:00, 136.22it/s, loss=0.43, v_num=og0h]
# Epoch 62:  87%|████████▋ | 240/275 [00:01<00:00, 130.34it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 62: 100%|██████████| 275/275 [00:02<00:00, 136.55it/s, loss=0.43, v_num=og0h]
# Epoch 63:  87%|████████▋ | 240/275 [00:01<00:00, 132.69it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 63: 100%|██████████| 275/275 [00:01<00:00, 138.91it/s, loss=0.429, v_num=og0h]
# Epoch 64:  87%|████████▋ | 240/275 [00:01<00:00, 130.57it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 64: 100%|██████████| 275/275 [00:02<00:00, 136.87it/s, loss=0.429, v_num=og0h]
# Epoch 65:  87%|████████▋ | 240/275 [00:01<00:00, 132.92it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 65: 100%|██████████| 275/275 [00:01<00:00, 139.33it/s, loss=0.429, v_num=og0h]
# Epoch 66:  87%|████████▋ | 240/275 [00:01<00:00, 133.07it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 66: 100%|██████████| 275/275 [00:01<00:00, 139.25it/s, loss=0.429, v_num=og0h]
# Epoch 67:  87%|████████▋ | 240/275 [00:01<00:00, 129.38it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 67: 100%|██████████| 275/275 [00:02<00:00, 135.79it/s, loss=0.43, v_num=og0h]
# Epoch 68:  87%|████████▋ | 240/275 [00:01<00:00, 131.07it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 68: 100%|██████████| 275/275 [00:02<00:00, 137.28it/s, loss=0.43, v_num=og0h]
# Epoch 69:  87%|████████▋ | 240/275 [00:01<00:00, 133.61it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 69: 100%|██████████| 275/275 [00:01<00:00, 139.82it/s, loss=0.429, v_num=og0h]
# Epoch 70:  87%|████████▋ | 240/275 [00:01<00:00, 130.36it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 70: 100%|██████████| 275/275 [00:02<00:00, 136.81it/s, loss=0.429, v_num=og0h]
# Epoch 71:  87%|████████▋ | 240/275 [00:01<00:00, 133.50it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 71: 100%|██████████| 275/275 [00:01<00:00, 139.71it/s, loss=0.429, v_num=og0h]
# Epoch 72:  87%|████████▋ | 240/275 [00:01<00:00, 133.87it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 72: 100%|██████████| 275/275 [00:01<00:00, 139.93it/s, loss=0.429, v_num=og0h]
# Epoch 73:  87%|████████▋ | 240/275 [00:01<00:00, 129.57it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 73: 100%|██████████| 275/275 [00:02<00:00, 135.90it/s, loss=0.429, v_num=og0h]
# Epoch 74:  87%|████████▋ | 240/275 [00:01<00:00, 132.05it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 74: 100%|██████████| 275/275 [00:01<00:00, 138.19it/s, loss=0.429, v_num=og0h]
# Epoch 76:  87%|████████▋ | 240/275 [00:01<00:00, 127.94it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 76: 100%|██████████| 275/275 [00:02<00:00, 134.28it/s, loss=0.429, v_num=og0h]
# Epoch 77:  87%|████████▋ | 240/275 [00:01<00:00, 132.59it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 77: 100%|██████████| 275/275 [00:01<00:00, 138.92it/s, loss=0.429, v_num=og0h]
# Epoch 78:  87%|████████▋ | 240/275 [00:01<00:00, 132.73it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 78: 100%|██████████| 275/275 [00:01<00:00, 139.09it/s, loss=0.429, v_num=og0h]
# Epoch 79:  87%|████████▋ | 240/275 [00:01<00:00, 128.26it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 79: 100%|██████████| 275/275 [00:02<00:00, 134.67it/s, loss=0.429, v_num=og0h]
# Epoch 80:  87%|████████▋ | 240/275 [00:01<00:00, 133.17it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 80: 100%|██████████| 275/275 [00:01<00:00, 139.63it/s, loss=0.429, v_num=og0h]
# Epoch 81:  87%|████████▋ | 240/275 [00:01<00:00, 133.29it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 81: 100%|██████████| 275/275 [00:01<00:00, 139.58it/s, loss=0.429, v_num=og0h]
# Epoch 82:  87%|████████▋ | 240/275 [00:01<00:00, 131.50it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 82: 100%|██████████| 275/275 [00:01<00:00, 137.73it/s, loss=0.429, v_num=og0h]
# Epoch 83:  87%|████████▋ | 240/275 [00:01<00:00, 127.72it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 83: 100%|██████████| 275/275 [00:02<00:00, 134.00it/s, loss=0.428, v_num=og0h]
# Epoch 84:  87%|████████▋ | 240/275 [00:01<00:00, 130.58it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 84: 100%|██████████| 275/275 [00:02<00:00, 136.86it/s, loss=0.428, v_num=og0h]
# Epoch 85:  87%|████████▋ | 240/275 [00:01<00:00, 130.06it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 85: 100%|██████████| 275/275 [00:02<00:00, 136.36it/s, loss=0.428, v_num=og0h]
# Epoch 86:  87%|████████▋ | 240/275 [00:01<00:00, 129.58it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 86: 100%|██████████| 275/275 [00:02<00:00, 135.97it/s, loss=0.429, v_num=og0h]
# Epoch 87:  87%|████████▋ | 240/275 [00:01<00:00, 130.84it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 87: 100%|██████████| 275/275 [00:02<00:00, 136.80it/s, loss=0.429, v_num=og0h]
# Epoch 88:  87%|████████▋ | 240/275 [00:01<00:00, 130.66it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 88: 100%|██████████| 275/275 [00:02<00:00, 137.02it/s, loss=0.429, v_num=og0h]
# Epoch 89:  87%|████████▋ | 240/275 [00:01<00:00, 127.00it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 89: 100%|██████████| 275/275 [00:02<00:00, 133.40it/s, loss=0.429, v_num=og0h]
# Epoch 90:  87%|████████▋ | 240/275 [00:01<00:00, 132.84it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 90: 100%|██████████| 275/275 [00:01<00:00, 139.15it/s, loss=0.429, v_num=og0h]
# Epoch 91:  87%|████████▋ | 240/275 [00:01<00:00, 133.85it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 91: 100%|██████████| 275/275 [00:02<00:00, 137.16it/s, loss=0.429, v_num=og0h]
# Epoch 92:  87%|████████▋ | 240/275 [00:01<00:00, 132.79it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 92: 100%|██████████| 275/275 [00:01<00:00, 138.79it/s, loss=0.429, v_num=og0h]
# Epoch 93:  87%|████████▋ | 240/275 [00:01<00:00, 132.30it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 93: 100%|██████████| 275/275 [00:01<00:00, 138.52it/s, loss=0.43, v_num=og0h]
# Epoch 94:  87%|████████▋ | 240/275 [00:01<00:00, 132.86it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 94: 100%|██████████| 275/275 [00:01<00:00, 139.01it/s, loss=0.43, v_num=og0h]
# Epoch 95:  87%|████████▋ | 240/275 [00:01<00:00, 130.11it/s, loss=0.43, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 95: 100%|██████████| 275/275 [00:02<00:00, 136.43it/s, loss=0.429, v_num=og0h]
# Epoch 96:  87%|████████▋ | 240/275 [00:01<00:00, 133.39it/s, loss=0.429, v_num=og0h]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/40 [00:00<?, ?it/s]
# Epoch 96: 100%|██████████| 275/275 [00:01<00:00, 139.58it/s, loss=0.429, v_num=og0h]

# %%
def get_data_and_targets(dataset):
    data = torch.stack([dataset[i][0] for i in range(len(dataset))], dim=0)
    targets = torch.stack([dataset[i][1] for i in range(len(dataset))], dim=0)
    return data, targets


class TripletsDataModule(pl.LightningDataModule):
    def __init__(self, base_datamodule, n_samples_for_triplets=None, n_triplets=None, n_triplets_valid=None, batch_size=256):
        super(TripletsDataModule, self).__init__()
        self.base_datamodule = base_datamodule
        self.batch_size = batch_size
        self.n_samples_for_triplets = n_samples_for_triplets
        self.n_triplets = n_triplets
        if n_triplets_valid is None:
            n_triplets_valid = n_triplets
        self.n_triplets_valid = n_triplets_valid
    
    def setup(self, stage_name=None):
        self.train_ds = TripletDataset(*get_data_and_targets(self.base_datamodule.train_ds), data_size=self.n_samples_for_triplets, 
                                                max_samples=self.n_triplets)
        self.valid_ds = TripletDataset(*get_data_and_targets(self.base_datamodule.valid_ds), data_size=self.n_samples_for_triplets,
                                                max_samples=self.n_triplets_valid)

    def train_dataloader(self):
        return DataLoader(self.train_ds, batch_size=self.batch_size)
    
    def val_dataloader(self):
        return DataLoader(self.valid_ds, batch_size=2**11)

# %%
def cluster_data(self, dl, k=10):
    encodings, y_true = [], []
    self.eval()
    with torch.no_grad():
        for batch in dl:
            bx, by = batch
            enc = self.encoder(bx.cuda())
            encodings.append(enc)
            y_true.append(by)
    encodings = torch.cat(encodings, dim=0).detach().cpu().numpy()
    y_true = torch.cat(y_true, dim=0).detach().cpu().numpy()
    gmm = GaussianMixture(n_components=k, covariance_type='full')
    cluster_labels = gmm.fit_predict(encodings)
    return y_true, cluster_labels, encodings


model.cuda()
y_true, y_pred, _ = cluster_data(model, dm.val_dataloader())
cluster_acc(y_true, y_pred)
# Out:
# 0.9494

# %%
model.encoder[0][0].weight.mean(dim=0)
# Out:
# tensor([-0.0003,  0.0001,  0.0005,  ..., -0.0078, -0.0078,  0.0005],
#        device='cuda:0', grad_fn=<MeanBackward1>)

# %%
model.cuda()
y_true, y_pred, _ = model.cluster_data(dm.val_dataloader())
cluster_acc(y_true, y_pred)
# Out:
# 0.8623

# %%
cluster_acc(y_true, y_pred)
# Out:
# 0.43851666666666667

# %%
class TripletLossModule(pl.LightningModule):
    def __init__(self, n_neurons, margin=0.5, lr=1e-3, p=0.):
        super(TripletLossModule, self).__init__()
        self.save_hyperparameters()
        self.n_neurons = n_neurons
        layers = [nn.Sequential(nn.Linear(n_neurons[i-1], n_neurons[i]), nn.ELU(), nn.Dropout(p=p)) for i in range(1, len(n_neurons)-1)]
        layers.append(nn.Linear(n_neurons[-2], n_neurons[-1]))
        self.encoder = nn.Sequential(*layers)
        
    def configure_optimizers(self):
        opt = torch.optim.AdamW(self.parameters(), lr=self.hparams['lr'])
        return opt

    def shared_step(self, batch):
        enc = {k: self.encoder(v) for k, v in batch.items()}
        enc = {k: v / (torch.linalg.norm(v, dim=1, keepdims=True) + 1e-8) for k, v in enc.items()}
        pos_distance = torch.linalg.norm(enc['anchor'] - enc['positive'], dim=-1)
        neg_distance = torch.linalg.norm(enc['anchor'] - enc['negative'], dim=-1)
        pct_correct = (pos_distance < neg_distance).float().mean() * 100
        loss = (pos_distance - neg_distance + self.hparams['margin']).clamp(0)
        if not loss.isfinite().all():
            import pdb; pdb.set_trace()
        result = {'loss': loss.mean(), 'pct_correct': pct_correct}
        return result
    
    def training_step(self, batch, batch_idx):
        result = self.shared_step(batch)
        for k, v in result.items():
            self.log('train/' + k, v)
        return result
    
    def validation_step(self, batch, batch_idx):
        result = self.shared_step(batch)
        for k, v in result.items():
            self.log('valid/' + k, v)
        return result
        
    def cluster_data(self, dl, k=10):
        encodings, y_true = [], []
        self.eval()
        with torch.no_grad():
            for batch in dl:
                bx, by = batch
                enc = self.encoder(bx.cuda())
                encodings.append(enc)
                y_true.append(by)
        encodings = torch.cat(encodings, dim=0).detach().cpu().numpy()
        y_true = torch.cat(y_true, dim=0).detach().cpu().numpy()
        gmm = GaussianMixture(n_components=k, covariance_type='full')
        cluster_labels = gmm.fit_predict(encodings)
        return y_true, cluster_labels, encodings

import wandb
model = TripletLossModule([28**2 + 1000, 512, 512, 2048, 10], lr=3e-4, p=0.1)
dm.setup()
data_module = TripletsDataModule(dm, n_triplets=2**10, n_triplets_valid=2**15, batch_size=2**6)
logger = pl.loggers.WandbLogger(project='Corrupted_MNIST', group='triplets')

trainer = pl.Trainer(gpus=1, max_epochs=3000, progress_bar_refresh_rate=0, log_every_n_steps=1, logger=logger)
trainer.fit(model, data_module)
wandb.finish()
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: wandb version 0.10.21 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.19<br/>
#                 Syncing run <strong style="color:#cdcd00">true-sky-15</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/shukistern/Corrupted_MNIST" target="_blank">https://wandb.ai/shukistern/Corrupted_MNIST</a><br/>
#                 Run page: <a href="https://wandb.ai/shukistern/Corrupted_MNIST/runs/203decpi" target="_blank">https://wandb.ai/shukistern/Corrupted_MNIST/runs/203decpi</a><br/>
#                 Run data is saved locally in <code>/home/shuki/projects/VaDE/wandb/run-20210303_131813-203decpi</code><br/><br/>
#   | Name    | Type       | Params
# ---------------------------------------
# 0 | encoder | Sequential | 2.2 M
# ---------------------------------------
# 2.2 M     Trainable params
# 0         Non-trainable params
# 2.2 M     Total params
# Validation sanity check:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/shuki/projects/VaDE/vade/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: Your `IterableDataset` has `__len__` defined. In combination with multi-processing data loading (e.g. batch size > 1), this can lead to unintended side effects since the samples will be duplicated.
#   warnings.warn(*args, **kwargs)
# /home/shuki/projects/VaDE/vade/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, val dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0:  62%|██████▎   | 20/32 [00:00<00:00, 104.36it/s]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# /home/shuki/projects/VaDE/vade/lib/python3.8/site-packages/pytorch_lightning/utilities/distributed.py:50: UserWarning: The dataloader, train dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   warnings.warn(*args, **kwargs)
# Epoch 0: 100%|██████████| 32/32 [00:01<00:00, 16.24it/s, loss=0.353, v_num=ecpi]
# Epoch 1:  62%|██████▎   | 20/32 [00:00<00:00, 105.91it/s, loss=0.353, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 1: 100%|██████████| 32/32 [00:01<00:00, 16.10it/s, loss=0.211, v_num=ecpi]
# Epoch 2:  62%|██████▎   | 20/32 [00:00<00:00, 106.49it/s, loss=0.211, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 32/32 [00:01<00:00, 16.39it/s, loss=0.187, v_num=ecpi]
# Epoch 3:  62%|██████▎   | 20/32 [00:00<00:00, 107.34it/s, loss=0.187, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 3: 100%|██████████| 32/32 [00:01<00:00, 16.19it/s, loss=0.153, v_num=ecpi]
# Epoch 4:  62%|██████▎   | 20/32 [00:00<00:00, 105.65it/s, loss=0.153, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 4: 100%|██████████| 32/32 [00:02<00:00, 15.72it/s, loss=0.144, v_num=ecpi]
# Epoch 5:  62%|██████▎   | 20/32 [00:00<00:00, 107.79it/s, loss=0.144, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 32/32 [00:01<00:00, 16.19it/s, loss=0.139, v_num=ecpi]
# Epoch 6:  62%|██████▎   | 20/32 [00:00<00:00, 107.56it/s, loss=0.139, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 6: 100%|██████████| 32/32 [00:01<00:00, 16.04it/s, loss=0.14, v_num=ecpi]
# Epoch 7:  62%|██████▎   | 20/32 [00:00<00:00, 105.22it/s, loss=0.14, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 32/32 [00:01<00:00, 16.19it/s, loss=0.141, v_num=ecpi]
# Epoch 8:  62%|██████▎   | 20/32 [00:00<00:00, 106.99it/s, loss=0.141, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 8: 100%|██████████|
v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2541: 100%|██████████| 32/32 [00:02<00:00, 14.48it/s, loss=0.00114, v_num=ecpi]
# Epoch 2542:  62%|██████▎   | 20/32 [00:00<00:00, 102.92it/s, loss=0.00114, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2542: 100%|██████████| 32/32 [00:02<00:00, 15.98it/s, loss=0.00167, v_num=ecpi]
# Epoch 2543:  62%|██████▎   | 20/32 [00:00<00:00, 104.02it/s, loss=0.00167, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2543: 100%|██████████| 32/32 [00:02<00:00, 15.81it/s, loss=0.00114, v_num=ecpi]
# Epoch 2544:  62%|██████▎   | 20/32 [00:00<00:00, 102.13it/s, loss=0.00114, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2544: 100%|██████████| 32/32 [00:02<00:00, 15.75it/s, loss=0.00123, v_num=ecpi]
# Epoch 2545:  62%|██████▎   | 20/32 [00:00<00:00, 103.18it/s, loss=0.00123, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2545: 100%|██████████| 32/32 [00:02<00:00, 15.16it/s, loss=0.00222, v_num=ecpi]
# Epoch 2546:  62%|██████▎   | 20/32 [00:00<00:00, 104.19it/s, loss=0.00222, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2546: 100%|██████████| 32/32 [00:02<00:00, 15.59it/s, loss=0.00131, v_num=ecpi]
# Epoch 2547:  62%|██████▎   | 20/32 [00:00<00:00, 102.74it/s, loss=0.00131, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2547: 100%|██████████| 32/32 [00:02<00:00, 15.54it/s, loss=0.000877, v_num=ecpi]
# Epoch 2548:  62%|██████▎   | 20/32 [00:00<00:00, 103.42it/s, loss=0.000877, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2548: 100%|██████████| 32/32 [00:02<00:00, 15.92it/s, loss=0.00223, v_num=ecpi]
# Epoch 2549:  62%|██████▎   | 20/32 [00:00<00:00, 105.20it/s, loss=0.00223, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2549: 100%|██████████| 32/32 [00:02<00:00, 15.88it/s, loss=0.00307, v_num=ecpi]
# Epoch 2550:  62%|██████▎   | 20/32 [00:00<00:00, 102.31it/s, loss=0.00307, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2550: 100%|██████████| 32/32 [00:02<00:00, 15.44it/s, loss=0.00394, v_num=ecpi]
# Epoch 2551:  62%|██████▎   | 20/32 [00:00<00:00, 104.47it/s, loss=0.00394, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2551: 100%|██████████| 32/32 [00:02<00:00, 15.58it/s, loss=0.00269, v_num=ecpi]
# Epoch 2552:  62%|██████▎   | 20/32 [00:00<00:00, 104.00it/s, loss=0.00269, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2552: 100%|██████████| 32/32 [00:02<00:00, 15.77it/s, loss=0.00132, v_num=ecpi]
# Epoch 2553:  62%|██████▎   | 20/32 [00:00<00:00, 104.29it/s, loss=0.00132, v_num=ecpi]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/16 [00:00<?, ?it/s]
# Epoch 2553: 100%|██████████| 32/32 [00:02<00:00, 15.78it/s, loss=0.00133, v_num=ecpi]

# %%
class CombinedDataModule(pl.LightningDataModule):
    def __init__(self, base_datamodule, n_samples_for_triplets=None, n_triplets=None, batch_size=256):
        super(combinedDataModule, self).__init__()
        self.batch_size = batch_size
        self.base_datamodule = base_datamodule
        self.n_samples_for_triplets = n_samples_for_triplets
        self.n_triplets = n_triplets
    
    def setup(self, stage_name=None):
        self.train_ds = CombinedDataset(self.base_datamodule.train_ds, data_size=self.n_samples_for_triplets, 
                                                max_triplets=self.n_triplets)
        self.valid_ds = CombinedDataset(self.base_datamodule.valid_ds, data_size=self.n_samples_for_triplets,
                                                max_triplets=self.n_triplets)

    def train_dataloader(self):
        return DataLoader(self.train_ds, batch_size=self.batch_size)
    
    def val_dataloader(self):
        return DataLoader(self.valid_ds, batch_size=self.batch_size)
